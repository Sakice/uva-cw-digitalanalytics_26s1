# %% [markdown]
# # Session 3: Lists & Dictionaries
#
# **Today:** Storing multiple values in collections

# %% [markdown]
# ## Lists: Ordered Collections
#
# **List** = multiple items in order
#
# Use square brackets `[ ]`

# %%
# Create lists
ages = [22, 25, 19, 31, 28]
platforms = ['Instagram', 'TikTok', 'Twitter']
print(ages)
print(platforms)
# Out:
# [22, 25, 19, 31, 28]
# ['Instagram', 'TikTok', 'Twitter']

# %% [markdown]
# ## Accessing List Items
#
# ⚠️ **Python starts counting at 0!**
#
# ```
# ['Instagram', 'TikTok', 'Twitter']
#       0          1         2
# ```

# %%
platforms = ['Instagram', 'TikTok', 'Twitter']

# First item (index 0)
print(platforms[0])
# Out:
# Instagram

# %%
# Last item (use -1)
print(platforms[-1])

# %%
# Slice: get multiple items [start:end]
print(platforms[0:2])  # Get items 0 and 1 (not 2!)

# %% [markdown]
# ## Modifying Lists

# %%
likes = [100, 150, 200]

# Add to end
likes.append(250)
print(likes)

# %%
# Change item
likes[0] = 120
print(likes)

# %%
# Useful functions
numbers = [10, 50, 30, 70, 20]
print('Length:', len(numbers))
print('Sum:', sum(numbers))
print('Max:', max(numbers))

# %% [markdown]
# ## Dictionaries: Key-Value Pairs
#
# **Dictionary** = labeled data
#
# Use curly braces `{ }` with `key: value`

# %%
# Create dictionary
user = {
    'username': 'emma_j',
    'followers': 1500,
    'verified': True
}
print(user)
# Out:
# {'username': 'emma_j', 'followers': 1500, 'verified': True}

# %%
# Access by key
print(user['username'])
print(user['followers'])
# Out:
# emma_j
# 1500

# %%
# Add or update
user['followers'] = 1600  # Update
user['posts'] = 127       # Add new
print(user)

# %% [markdown]
# ## When to Use Each?
#
# **List:** Ordered items (survey scores, usernames)
# ```python
# scores = [7, 8, 6, 9]
# ```
#
# **Dictionary:** Describe one thing with attributes
# ```python
# user = {'name': 'Emma', 'age': 22}
# ```

# %% [markdown]
# ## 🎯 Practice Exercise

# %%
# 1. Create list: responses = [45, 67, 23, 89, 34]
responses = [45, 67, 23, 89, 34]

# %%
# 2. Print first and last response
print(responses[0], responses[-1])
# Out:
# 45 34

# %%
# 3. Calculate average (sum/length)
print(sum(responses)/len(responses))
# Out:
# 51.6

# %%
# 4. Create dict: post = {'platform': 'TikTok', 'views': 15000, 'likes': 2100}
post = {'platform': 'TikTok', 'views': 15000, 'likes': 2100}

# %%
# 5. Print the views
print(post['views'])
# Out:
# 15000

# %%
# 6. Add 'comments': 340 to the dictionary
post['comments'] = 340
print(post)
# Out:
# {'platform': 'TikTok', 'views': 15000, 'likes': 2100, 'comments': 340}

# %% [markdown]
# ## ✅ Key Takeaways
#
# * **Lists** `[item1, item2]` - ordered collections
# * Indexing starts at 0: `my_list[0]`
# * Negative indexing: `my_list[-1]` is last item
# * **Dictionaries** `{'key': value}` - labeled data
# * Access by key: `my_dict['key']`
# * Use lists for similar items, dicts for attributes
#
# **Next:** Conditions and loops!
